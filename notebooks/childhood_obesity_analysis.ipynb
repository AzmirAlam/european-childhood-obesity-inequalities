# %% [markdown]
# # Childhood Obesity and Health Inequalities in Europe
#
# Run the reproducible analysis using the included WHO European Region data.

# %%
from pathlib import Path
import sys
root = next(p for p in [Path.cwd(), Path.cwd().parent] if (p / 'src').exists())
sys.path.insert(0, str(root / 'src'))
from analyse_childhood_obesity import main
main()
